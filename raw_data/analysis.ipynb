# %%
import pandas as pd

# %%
df = pd.read_csv('BPIC_2012_W.csv')
df
# Out:
#        Unnamed: 0                    concept:name lifecycle:transition  \
# 0               0          W_Completeren aanvraag             complete
# 1               1          W_Completeren aanvraag             complete
# 2               2          W_Completeren aanvraag             complete
# 3               3              W_Afhandelen leads             complete
# 4               4          W_Completeren aanvraag             complete
# ...           ...                             ...                  ...
# 59297       59297  W_Nabellen incomplete dossiers             complete
# 59298       59298  W_Nabellen incomplete dossiers             complete
# 59299       59299            W_Valideren aanvraag             complete
# 59300       59300  W_Nabellen incomplete dossiers             complete
# 59301       59301            W_Valideren aanvraag             complete
#
#       org:resource                    time:timestamp  \
# 0          10861.0  2011-12-30 12:16:37.140000+00:00
# ...

# %%
len(df['Resource'].unique())
# Out:
# 58
